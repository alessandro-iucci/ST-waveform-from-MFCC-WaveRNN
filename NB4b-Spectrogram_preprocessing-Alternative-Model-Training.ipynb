# %% [markdown]
# ## Alternative Model (Training)
#
# I've found WaveRNN quite slow to train so here's an alternative that utilises the optimised rnn kernels in Pytorch. The model below is much much faster to train, it will converge in 48hrs when training on 22.5kHz samples (or 24hrs using 16kHz samples) on a single GTX1080. It also works quite well with predicted GTA features.
#
# The model is simply two residual GRUs in sequence and then three dense layers with a 512 softmax output. This is supplemented with an upsampling network.
#
# Since the Pytorch rnn kernels are 'closed', the options for conditioning sites are greatly reduced. Here's the strategy I went with given that restriction:
#
# 1 - Upsampling: Nearest neighbour upsampling followed by 2d convolutions with 'horizontal' kernels to interpolate. Split up into two or three layers depending on the stft hop length.
#
# 2 - A 1d resnet with a 5 wide conv input and 1x1 res blocks. Not sure if this is necessary, but the thinking behind it is: the upsampled features give a local view of the conditioning - why not supplement that with a much wider view of conditioning features, including a peek at the future. One thing to note is that the resnet is computed only once and in parallel, so it shouldn't slow down training/generation much.
#
# Train this model to ~500k steps for 8/9bit linear samples or ~1M steps for 10bit linear or 9+bit mu_law.

# %%
# %matplotlib inline
import math, pickle, os
import numpy as np
import torch
from torch import optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from utils.display import *
from utils.dsp import *

# %%
bits = 9
pad = 2
seq_len = hop_length * 5
seq_len
# Out:
# 1375

# %%
notebook_name = 'nb4'

# %%
# %mkdir -p 'model_checkpoints/'
# Out:
# La syntaxe de la commande n'est pas correcte.

# %%
MODEL_PATH = f'model_checkpoints/{notebook_name}.pyt'
DATA_PATH = f'D:/Workspace/DT2112/WaveRNN-master/notebooks/nb4a/data/'
STEP_PATH = f'model_checkpoints/{notebook_name}_step.npy'
GEN_PATH = f'model_outputs/{notebook_name}/'
# %mkdir -p $GEN_PATH
# Out:
# La syntaxe de la commande n'est pas correcte.

# %% [markdown]
# ## Dataset

# %%
with open(f'{DATA_PATH}dataset_ids.pkl', 'rb') as f:
    dataset_ids = pickle.load(f)

# %%
test_ids = dataset_ids
dataset_ids = dataset_ids

# %%
class AudiobookDataset(Dataset):
    def __init__(self, ids, path):
        self.path = path
        self.metadata = ids
        
    def __getitem__(self, index):
        file = self.metadata[index]
        m = np.load(f'{self.path}mel/{file}.npy')
        x = np.load(f'{self.path}quant/{file}.npy')
        return m, x

    def __len__(self):
        return len(self.metadata)

# %%
def collate(batch) :
    
    mel_win = seq_len // hop_length + 2 * pad
    max_offsets = [x[0].shape[-1] - (mel_win + 2 * pad) for x in batch]
    mel_offsets = [np.random.randint(0, offset) for offset in max_offsets]
    sig_offsets = [(offset + pad) * hop_length for offset in mel_offsets]
    
    mels = [x[0][:, mel_offsets[i]:mel_offsets[i] + mel_win] \
            for i, x in enumerate(batch)]
    
    coarse = [x[1][sig_offsets[i]:sig_offsets[i] + seq_len + 1] \
              for i, x in enumerate(batch)]
    
    mels = np.stack(mels).astype(np.float32)
    coarse = np.stack(coarse).astype(np.int64)
    
    mels = torch.FloatTensor(mels)
    coarse = torch.LongTensor(coarse)
    
    x_input = 2 * coarse[:, :seq_len].float() / (2**bits - 1.) - 1.
    
    y_coarse = coarse[:, 1:]
    
    return x_input, mels, y_coarse

# %%
dataset = AudiobookDataset(dataset_ids, DATA_PATH)

# %%
data_loader = DataLoader(dataset, collate_fn=collate, batch_size=32, 
                         num_workers=0, shuffle=True)

# %%
len(dataset)
# Out:
# 1120

# %%
x, m, y = next(iter(data_loader))
x.shape, m.shape, y.shape
# Out:
# (torch.Size([32, 1375]), torch.Size([32, 80, 9]), torch.Size([32, 1375]))

# %%
plot(x.numpy()[0]) 
plot(y.numpy()[0])
plot_spec(m.numpy()[0])

# %% [markdown]
# ## Define Model Classes

# %%
class ResBlock(nn.Module) :
    def __init__(self, dims) :
        super().__init__()
        self.conv1 = nn.Conv1d(dims, dims, kernel_size=1, bias=False)
        self.conv2 = nn.Conv1d(dims, dims, kernel_size=1, bias=False)
        self.batch_norm1 = nn.BatchNorm1d(dims)
        self.batch_norm2 = nn.BatchNorm1d(dims)
        
    def forward(self, x) :
        residual = x
        x = self.conv1(x)
        x = self.batch_norm1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = self.batch_norm2(x)
        return x + residual

# %%
class MelResNet(nn.Module) :
    def __init__(self, res_blocks, in_dims, compute_dims, res_out_dims) :
        super().__init__()
        k_size = pad * 2 + 1
        self.conv_in = nn.Conv1d(in_dims, compute_dims, kernel_size=k_size, bias=False)
        self.batch_norm = nn.BatchNorm1d(compute_dims)
        self.layers = nn.ModuleList()
        for i in range(res_blocks) :
            self.layers.append(ResBlock(compute_dims))
        self.conv_out = nn.Conv1d(compute_dims, res_out_dims, kernel_size=1)
        
    def forward(self, x) :
        x = self.conv_in(x)
        x = self.batch_norm(x)
        x = F.relu(x)
        for f in self.layers : x = f(x)
        x = self.conv_out(x)
        return x

# %%
class Stretch2d(nn.Module) :
    def __init__(self, x_scale, y_scale) :
        super().__init__()
        self.x_scale = x_scale
        self.y_scale = y_scale
        
    def forward(self, x) :
        b, c, h, w = x.size()
        x = x.unsqueeze(-1).unsqueeze(3)
        x = x.repeat(1, 1, 1, self.y_scale, 1, self.x_scale)
        return x.view(b, c, h * self.y_scale, w * self.x_scale)

# %%
class UpsampleNetwork(nn.Module) :
    def __init__(self, feat_dims, upsample_scales, compute_dims, 
                 res_blocks, res_out_dims, pad) :
        super().__init__()
        total_scale = np.cumproduct(upsample_scales)[-1]
        self.indent = pad * total_scale
        self.resnet = MelResNet(res_blocks, feat_dims, compute_dims, res_out_dims)
        self.resnet_stretch = Stretch2d(total_scale, 1)
        self.up_layers = nn.ModuleList()
        for scale in upsample_scales :
            k_size = (1, scale * 2 + 1)
            padding = (0, scale)
            stretch = Stretch2d(scale, 1)
            conv = nn.Conv2d(1, 1, kernel_size=k_size, padding=padding, bias=False)
            conv.weight.data.fill_(1. / k_size[1])
            self.up_layers.append(stretch)
            self.up_layers.append(conv)
    
    def forward(self, m) :
        aux = self.resnet(m).unsqueeze(1)
        aux = self.resnet_stretch(aux)
        aux = aux.squeeze(1)
        m = m.unsqueeze(1)
        for f in self.up_layers : m = f(m)
        m = m.squeeze(1)[:, :, self.indent:-self.indent]
        return m.transpose(1, 2), aux.transpose(1, 2)

# %%
class Model(nn.Module) :
    def __init__(self, rnn_dims, fc_dims, bits, pad, upsample_factors,
                 feat_dims, compute_dims, res_out_dims, res_blocks,
                 hop_length, sample_rate):
        super().__init__()
        self.pad = pad
        self.n_classes = 2**bits
        self.rnn_dims = rnn_dims
        self.aux_dims = res_out_dims // 4
        self.hop_length = hop_length
        self.sample_rate = sample_rate
        self.upsample = UpsampleNetwork(feat_dims, upsample_factors, compute_dims, 
                                        res_blocks, res_out_dims, pad)
        self.I = nn.Linear(feat_dims + self.aux_dims + 1, rnn_dims)
        self.rnn1 = nn.GRU(rnn_dims, rnn_dims, batch_first=True)
        self.rnn2 = nn.GRU(rnn_dims + self.aux_dims, rnn_dims, batch_first=True)
        self.fc1 = nn.Linear(rnn_dims + self.aux_dims, fc_dims)
        self.fc2 = nn.Linear(fc_dims + self.aux_dims, fc_dims)
        self.fc3 = nn.Linear(fc_dims, self.n_classes)
        num_params(self)
    
    
    def forward(self, x, mels) :
        bsize = x.size(0)
        h1 = torch.zeros(1, bsize, self.rnn_dims).cuda()
        h2 = torch.zeros(1, bsize, self.rnn_dims).cuda()
        mels, aux = self.upsample(mels)
        
        aux_idx = [self.aux_dims * i for i in range(5)]
        a1 = aux[:, :, aux_idx[0]:aux_idx[1]]
        a2 = aux[:, :, aux_idx[1]:aux_idx[2]]
        a3 = aux[:, :, aux_idx[2]:aux_idx[3]]
        a4 = aux[:, :, aux_idx[3]:aux_idx[4]]
        
        x = torch.cat([x.unsqueeze(-1), mels, a1], dim=2)
        x = self.I(x)
        res = x
        x, _ = self.rnn1(x, h1)
        
        x = x + res
        res = x
        x = torch.cat([x, a2], dim=2)
        x, _ = self.rnn2(x, h2)
        
        x = x + res
        x = torch.cat([x, a3], dim=2)
        x = F.relu(self.fc1(x))
        
        x = torch.cat([x, a4], dim=2)
        x = F.relu(self.fc2(x))
        return F.log_softmax(self.fc3(x), dim=-1)
    
    
    def generate(self, mels, save_path, batched, target, overlap) :
        
        self.eval()
        output = []
        start = time.time()
        rnn1 = self.get_gru_cell(self.rnn1)
        rnn2 = self.get_gru_cell(self.rnn2)
        
        with torch.no_grad() :
            
            mels = torch.FloatTensor(mels).cuda().unsqueeze(0)
            mels = self.pad_tensor(mels.transpose(1, 2), pad=self.pad, side='both')
            mels, aux = self.upsample(mels.transpose(1, 2))
            
            if batched :
                mels = self.fold_with_overlap(mels, target, overlap)
                aux = self.fold_with_overlap(aux, target, overlap)

            b_size, seq_len, _ = mels.size()
            
            h1 = torch.zeros(b_size, self.rnn_dims).cuda()
            h2 = torch.zeros(b_size, self.rnn_dims).cuda()
            x = torch.zeros(b_size, 1).cuda()
            
            d = self.aux_dims
            aux_split = [aux[:, :, d*i:d*(i+1)] for i in range(4)]
            
            for i in range(seq_len) :

                m_t = mels[:, i, :]
                
                a1_t, a2_t, a3_t, a4_t = \
                    (a[:, i, :] for a in aux_split)
                
                x = torch.cat([x, m_t, a1_t], dim=1)
                x = self.I(x)
                h1 = rnn1(x, h1)
                
                x = x + h1
                inp = torch.cat([x, a2_t], dim=1)
                h2 = rnn2(inp, h2)
                
                x = x + h2
                x = torch.cat([x, a3_t], dim=1)
                x = F.relu(self.fc1(x))
                
                x = torch.cat([x, a4_t], dim=1)
                x = F.relu(self.fc2(x))
                
                logits = self.fc3(x)
                posterior = F.softmax(logits, dim=1)
                distrib = torch.distributions.Categorical(posterior)
                
                sample = 2 * distrib.sample().float() / (self.n_classes - 1.) - 1.
                output.append(sample)
                x = sample.unsqueeze(-1)
                
                if i % 100 == 0 : self.gen_display(i, seq_len, b_size, start)
                    
        
        output = torch.stack(output).transpose(0, 1)
        output = output.cpu().numpy()
        output = output.astype(np.float64)
        
        if batched :
            output = self.xfade_and_unfold(output, target, overlap)
        else :
            output = output[0]
            
        librosa.output.write_wav(save_path, output.astype(np.float32), self.sample_rate)
        
        self.train()
        
        return output
    
    def gen_display(self, i, seq_len, b_size, start) :
        gen_rate = (i + 1) / (time.time() - start) * b_size / 1000 
        realtime_ratio = gen_rate * 1000 / self.sample_rate
        stream('%i/%i -- batch_size: %i -- gen_rate: %.1f kHz -- x_realtime: %.1f  ', 
              (i * b_size, seq_len * b_size, b_size, gen_rate, realtime_ratio))
    
    def get_gru_cell(self, gru) :
        gru_cell = nn.GRUCell(gru.input_size, gru.hidden_size)
        gru_cell.weight_hh.data = gru.weight_hh_l0.data
        gru_cell.weight_ih.data = gru.weight_ih_l0.data
        gru_cell.bias_hh.data = gru.bias_hh_l0.data
        gru_cell.bias_ih.data = gru.bias_ih_l0.data
        return gru_cell
    
    
    def pad_tensor(self, x, pad, side='both') :
        # NB - this is just a quick method i need right now
        # i.e., it won't generalise to other shapes/dims
        b, t, c = x.size()
        total = t + 2 * pad if side == 'both' else t + pad
        padded = torch.zeros(b, total, c).cuda()
        if side == 'before' or side == 'both' :
            padded[:, pad:pad+t, :] = x
        elif side == 'after' :
            padded[:, :t, :] = x    
        return padded

    
    def fold_with_overlap(self, x, target, overlap) :
        
        ''' Fold the tensor with overlap for quick batched inference.
            Overlap will be used for crossfading in xfade_and_unfold()

        Args:
            x (tensor)    : Upsampled conditioning features. 
                            shape=(1, timesteps, features)
            target (int)  : Target timesteps for each index of batch
            overlap (int) : Timesteps for both xfade and rnn warmup

        Return:
            (tensor) : shape=(num_folds, target + 2 * overlap, features)
         
        Details:      
            x = [[h1, h2, ... hn]] 

            Where each h is a vector of conditioning features

            Eg: target=2, overlap=1 with x.size(1)=10 

            folded = [[h1, h2, h3, h4],
                      [h4, h5, h6, h7],
                      [h7, h8, h9, h10]]
        '''

        _, total_len, features = x.size()
        
        # Calculate variables needed
        num_folds = (total_len - overlap) // (target + overlap)
        extended_len = num_folds * (overlap + target) + overlap
        remaining = total_len - extended_len
        
        # Pad if some time steps poking out
        if remaining != 0 :
            num_folds += 1
            padding = target + 2 * overlap - remaining    
            x = self.pad_tensor(x, padding, side='after')

        folded = torch.zeros(num_folds, target + 2 * overlap, features).cuda()
        
        # Get the values for the folded tensor
        for i in range(num_folds) :
            start = i * (target + overlap)
            end = start + target + 2 * overlap
            folded[i] = x[:, start:end, :]

        return folded
    
    
    def xfade_and_unfold(self, y, target, overlap) :
        
        ''' Applies a crossfade and unfolds into a 1d array.
            
        Args:
            y (ndarry)    : Batched sequences of audio samples
                            shape=(num_folds, target + 2 * overlap)
                            dtype=np.float64
            overlap (int) : Timesteps for both xfade and rnn warmup

        Return:
            (ndarry) : audio samples in a 1d array  
                       shape=(total_len)
                       dtype=np.float64
        
        Details: 
            y = [[seq1], 
                 [seq2], 
                 [seq3]] 
            
            Apply a gain envelope at both ends of the sequences
        
            y = [[seq1_in, seq1_target, seq1_out],
                 [seq2_in, seq2_target, seq2_out],
                 [seq3_in, seq3_target, seq3_out]]

            Stagger and add up the groups of samples:

            [seq1_in, seq1_target, (seq1_out + seq2_in), seq2_target, ...]
            
        '''
        
        num_folds, length = y.shape
        target = length - 2 * overlap
        total_len = num_folds * (target + overlap) + overlap
        
        # Need some silence for the rnn warmup
        silence_len = overlap // 2
        fade_len = overlap - silence_len
        silence = np.zeros((silence_len), dtype=np.float64)
        
        # Equal power crossfade
        t = np.linspace(-1, 1, fade_len, dtype=np.float64)
        fade_in = np.sqrt(0.5 * (1 + t))
        fade_out = np.sqrt(0.5 * (1 - t))
        
        # Concat the silence to the fades
        fade_in = np.concatenate([silence, fade_in])
        fade_out = np.concatenate([fade_out, silence])
        
        # Apply the gain to the overlap samples
        y[:, :overlap] *= fade_in
        y[:, -overlap:] *= fade_out
        
        unfolded = np.zeros((total_len), dtype=np.float64)
        
        # Loop to add up all the samples
        for i in range(num_folds ) :
            start = i * (target + overlap)
            end = start + target + 2 * overlap
            unfolded[start:end] += y[i]

        return unfolded

# %% [markdown]
# ## Instantiate and Check Upsampling

# %%
model = Model(rnn_dims=512, 
              fc_dims=512, 
              bits=bits,
              pad=pad,
              upsample_factors=(5, 5, 11), 
              feat_dims=80,
              compute_dims=128, 
              res_out_dims=128, 
              res_blocks=10,
              hop_length=hop_length,
              sample_rate=sample_rate).cuda()
# Out:
# Trainable Parameters: 4.481 million

# %%
if not os.path.exists(MODEL_PATH):
    torch.save(model.state_dict(), MODEL_PATH) 
model.load_state_dict(torch.load(MODEL_PATH))

# %%
mels, aux = model.upsample(m.cuda())

# %%
plot_spec(m[0].numpy())
plot_spec(mels[0].cpu().detach().numpy().T)

# %%
global step
step = 0

# %%
if not os.path.exists(STEP_PATH):
    np.save(STEP_PATH, step)
step = np.load(STEP_PATH)
step
# Out:
# array(25687)

# %%
def train(model, optimiser, epochs, batch_size, classes, seq_len, step, lr=1e-4) :
        
    for p in optimiser.param_groups : p['lr'] = lr
    criterion = nn.NLLLoss().cuda()
    
    for e in range(epochs) :

        trn_loader = DataLoader(dataset, collate_fn=collate, batch_size=batch_size, 
                                num_workers=0, shuffle=True, pin_memory=True)
    
        running_loss = 0.
        val_loss = 0.
        start = time.time()
        running_loss = 0.

        iters = len(trn_loader)

        for i, (x, m, y) in enumerate(trn_loader) :
            
            x, m, y = x.cuda(), m.cuda(), y.cuda()

            y_hat = model(x, m)
            y_hat = y_hat.transpose(1, 2).unsqueeze(-1)
            y = y.unsqueeze(-1)
            loss = criterion(y_hat, y)
            
            optimiser.zero_grad()
            loss.backward()
            optimiser.step()
            running_loss += loss.item()
            
            speed = (i + 1) / (time.time() - start)
            avg_loss = running_loss / (i + 1)
            
            step += 1
            k = step // 1000
            stream('Epoch: %i/%i -- Batch: %i/%i -- Loss: %.3f -- %.2f steps/sec -- Step: %ik ', 
                   (e + 1, epochs, i + 1, iters, avg_loss, speed, k))
        
        torch.save(model.state_dict(), MODEL_PATH)
        np.save(STEP_PATH, step)
        print(' <saved>')

# %%
optimiser = optim.Adam(model.parameters())

# %%
train(model, optimiser, epochs=200, batch_size=14, classes=2**bits, 
      seq_len=seq_len, step=step, lr=1e-4)
# Out:
# Epoch: 1/200 -- Batch: 80/80 -- Loss: 1.711 -- 0.64 steps/sec -- Step: 9k  <saved>
# Epoch: 2/200 -- Batch: 80/80 -- Loss: 1.625 -- 0.64 steps/sec -- Step: 9k  <saved>
# Epoch: 3/200 -- Batch: 80/80 -- Loss: 1.602 -- 0.64 steps/sec -- Step: 9k  <saved>
# Epoch: 4/200 -- Batch: 80/80 -- Loss: 1.634 -- 0.65 steps/sec -- Step: 10k  <saved>
# Epoch: 5/200 -- Batch: 80/80 -- Loss: 1.633 -- 0.65 steps/sec -- Step: 10k  <saved>
# Epoch: 6/200 -- Batch: 80/80 -- Loss: 1.595 -- 0.64 steps/sec -- Step: 10k  <saved>
# Epoch: 7/200 -- Batch: 80/80 -- Loss: 1.614 -- 0.63 steps/sec -- Step: 10k  <saved>
# Epoch: 8/200 -- Batch: 80/80 -- Loss: 1.610 -- 0.63 steps/sec -- Step: 10k  <saved>
# Epoch: 9/200 -- Batch: 80/80 -- Loss: 1.616 -- 0.64 steps/sec -- Step: 10k  <saved>
# Epoch: 10/200 -- Batch: 80/80 -- Loss: 1.602 -- 0.65 steps/sec -- Step: 10k  <saved>
# Epoch: 11/200 -- Batch: 80/80 -- Loss: 1.613 -- 0.66 steps/sec -- Step: 10k  <saved>
# Epoch: 12/200 -- Batch: 80/80 -- Loss: 1.641 -- 0.65 steps/sec -- Step: 10k  <saved>
# Epoch: 13/200 -- Batch: 80/80 -- Loss: 1.595 -- 0.64 steps/sec -- Step: 10k  <saved>
# Epoch: 14/200 -- Batch: 80/80 -- Loss: 1.640 -- 0.65 steps/sec -- Step: 10k  <saved>
# Epoch: 15/200 -- Batch: 80/80 -- Loss: 1.621 -- 0.64 steps/sec -- Step: 10k  <saved>
# Epoch: 16/200 -- Batch: 80/80 -- Loss: 1.613 -- 0.64 steps/sec -- Step: 10k  <saved>
# Epoch: 17/200 -- Batch: 80/80 -- Loss: 1.612 -- 0.66 steps/sec -- Step: 11k  <saved>
# Epoch: 18/200 -- Batch: 80/80 -- Loss: 1.603 -- 0.66 steps/sec -- Step: 11k  <saved>
# Epoch: 19/200 -- Batch: 80/80 -- Loss: 1.619 -- 0.66 steps/sec -- Step: 11k  <saved>
# Epoch: 20/200 -- Batch: 80/80 -- Loss: 1.617 -- 0.65 steps/sec -- Step: 11k  <saved>
# Epoch: 21/200 -- Batch: 80/80 -- Loss: 1.588 -- 0.65 steps/sec -- Step: 11k  <saved>
# Epoch: 22/200 -- Batch: 80/80 -- Loss: 1.579 -- 0.66 steps/sec -- Step: 11k  <saved>
# Epoch: 23/200 -- Batch: 80/80 -- Loss: 1.556 -- 0.65 steps/sec -- Step: 11k  <saved>
# Epoch: 24/200 -- Batch: 80/80 -- Loss: 1.590 -- 0.65 steps/sec -- Step: 11k  <saved>
# Epoch: 25/200 -- Batch: 80/80 -- Loss: 1.587 -- 0.65 steps/sec -- Step: 11k  <saved>
# Epoch: 26/200 -- Batch: 80/80 -- Loss: 1.591 -- 0.66 steps/sec -- Step: 11k  <saved>
# Epoch: 27/200 -- Batch: 80/80 -- Loss: 1.581 -- 0.66 steps/sec -- Step: 11k  <saved>
# Epoch: 28/200 -- Batch: 80/80 -- Loss: 1.597 -- 0.66 steps/sec -- Step: 11k  <saved>
# Epoch: 29/200 -- Batch: 80/80 -- Loss: 1.574 -- 0.66 steps/sec -- Step: 12k  <saved>
# Epoch: 30/200 -- Batch: 80/80 -- Loss: 1.546 -- 0.66 steps/sec -- Step: 12k  <saved>
# Epoch: 31/200 -- Batch: 80/80 -- Loss: 1.603 -- 0.66 steps/sec -- Step: 12k  <saved>
# Epoch: 32/200 -- Batch: 80/80 -- Loss: 1.574 -- 0.66 steps/sec -- Step: 12k  <saved>
# Epoch: 33/200 -- Batch: 80/80 -- Loss: 1.599 -- 0.66 steps/sec -- Step: 12k  <saved>
# Epoch: 34/200 -- Batch: 80/80 -- Loss: 1.592 -- 0.66 steps/sec -- Step: 12k  <saved>
# Epoch: 35/200 -- Batch: 80/80 -- Loss: 1.623 -- 0.66 steps/sec -- Step: 12k  <saved>
# Epoch: 36/200 -- Batch: 80/80 -- Loss: 1.587 -- 0.66 steps/sec -- Step: 12k  <saved>
# Epoch: 37/200 -- Batch: 80/80 -- Loss: 1.547 -- 0.66 steps/sec -- Step: 12k  <saved>
# Epoch: 38/200 -- Batch: 80/80 -- Loss: 1.562 -- 0.66 steps/sec -- Step: 12k  <saved>
# Epoch: 39/200 -- Batch: 80/80 -- Loss: 1.599 -- 0.66 steps/sec -- Step: 12k  <saved>
# Epoch: 40/200 -- Batch: 80/80 -- Loss: 1.559 -- 0.66 steps/sec -- Step: 12k  <saved>
# Epoch: 41/200 -- Batch: 80/80 -- Loss: 1.561 -- 0.66 steps/sec -- Step: 12k  <saved>
# Epoch: 42/200 -- Batch: 80/80 -- Loss: 1.588 -- 0.66 steps/sec -- Step: 13k  <saved>
# Epoch: 43/200 -- Batch: 80/80 -- Loss: 1.586 -- 0.66 steps/sec -- Step: 13k  <saved>
# Epoch: 44/200 -- Batch: 80/80 -- Loss: 1.569 -- 0.66 steps/sec -- Step: 13k  <saved>
# Epoch: 45/200 -- Batch: 80/80 -- Loss: 1.548 -- 0.66 steps/sec -- Step: 13k  <saved>
# Epoch: 46/200 -- Batch: 80/80 -- Loss: 1.545 -- 0.66 steps/sec -- Step: 13k  <saved>
# Epoch: 47/200 -- Batch: 80/80 -- Loss: 1.584 -- 0.66 steps/sec -- Step: 13k  <saved>
# Epoch: 48/200 -- Batch: 80/80 -- Loss: 1.581 -- 0.66 steps/sec -- Step: 13k  <saved>
# Epoch: 49/200 -- Batch: 80/80 -- Loss: 1.571 -- 0.66 steps/sec -- Step: 13k  <saved>
# Epoch: 50/200 -- Batch: 80/80 -- Loss: 1.554 -- 0.66 steps/sec -- Step: 13k  <saved>
# Epoch: 51/200 -- Batch: 80/80 -- Loss: 1.599 -- 0.66 steps/sec -- Step: 13k  <saved>
# Epoch: 52/200 -- Batch: 80/80 -- Loss: 1.562 -- 0.66 steps/sec -- Step: 13k  <saved>
# Epoch: 53/200 -- Batch: 80/80 -- Loss: 1.558 -- 0.66 steps/sec -- Step: 13k  <saved>
# Epoch: 54/200 -- Batch: 80/80 -- Loss: 1.587 -- 0.66 steps/sec -- Step: 14k  <saved>
# Epoch: 55/200 -- Batch: 80/80 -- Loss: 1.574 -- 0.66 steps/sec -- Step: 14k  <saved>
# Epoch: 56/200 -- Batch: 80/80 -- Loss: 1.571 -- 0.66 steps/sec -- Step: 14k  <saved>
# Epoch: 57/200 -- Batch: 80/80 -- Loss: 1.548 -- 0.66 steps/sec -- Step: 14k  <saved>
# Epoch: 58/200 -- Batch: 80/80 -- Loss: 1.574 -- 0.66 steps/sec -- Step: 14k  <saved>
# Epoch: 59/200 -- Batch: 80/80 -- Loss: 1.589 -- 0.66 steps/sec -- Step: 14k  <saved>
# Epoch: 60/200 -- Batch: 80/80 -- Loss: 1.561 -- 0.66 steps/sec -- Step: 14k  <saved>
# Epoch: 61/200 -- Batch: 80/80 -- Loss: 1.581 -- 0.66 steps/sec -- Step: 14k  <saved>
# Epoch: 62/200 -- Batch: 80/80 -- Loss: 1.588 -- 0.66 steps/sec -- Step: 14k  <saved>
# Epoch: 63/200 -- Batch: 80/80 -- Loss: 1.594 -- 0.66 steps/sec -- Step: 14k  <saved>
# Epoch: 64/200 -- Batch: 80/80 -- Loss: 1.563 -- 0.66 steps/sec -- Step: 14k  <saved>
# Epoch: 65/200 -- Batch: 80/80 -- Loss: 1.562 -- 0.66 steps/sec -- Step: 14k  <saved>
# Epoch: 66/200 -- Batch: 80/80 -- Loss: 1.561 -- 0.66 steps/sec -- Step: 14k  <saved>
# Epoch: 67/200 -- Batch: 80/80 -- Loss: 1.546 -- 0.66 steps/sec -- Step: 15k  <saved>
# Epoch: 68/200 -- Batch: 80/80 -- Loss: 1.560 -- 0.66 steps/sec -- Step: 15k  <saved>
# Epoch: 69/200 -- Batch: 80/80 -- Loss: 1.508 -- 0.66 steps/sec -- Step: 15k  <saved>
# Epoch: 70/200 -- Batch: 80/80 -- Loss: 1.568 -- 0.66 steps/sec -- Step: 15k  <saved>
# Epoch: 71/200 -- Batch: 80/80 -- Loss: 1.547 -- 0.66 steps/sec -- Step: 15k  <saved>
# Epoch: 72/200 -- Batch: 80/80 -- Loss: 1.558 -- 0.66 steps/sec -- Step: 15k  <saved>
# Epoch: 73/200 -- Batch: 80/80 -- Loss: 1.548 -- 0.66 steps/sec -- Step: 15k  <saved>
# Epoch: 74/200 -- Batch: 80/80 -- Loss: 1.569 -- 0.66 steps/sec -- Step: 15k  <saved>
# Epoch: 75/200 -- Batch: 80/80 -- Loss: 1.524 -- 0.66 steps/sec -- Step: 15k  <saved>
# Epoch: 76/200 -- Batch: 80/80 -- Loss: 1.507 -- 0.66 steps/sec -- Step: 15k  <saved>
# Epoch: 77/200 -- Batch: 80/80 -- Loss: 1.541 -- 0.66 steps/sec -- Step: 15k  <saved>
# Epoch: 78/200 -- Batch: 80/80 -- Loss: 1.549 -- 0.66 steps/sec -- Step: 15k  <saved>
# Epoch: 79/200 -- Batch: 80/80 -- Loss: 1.566 -- 0.66 steps/sec -- Step: 16k  <saved>
# Epoch: 80/200 -- Batch: 80/80 -- Loss: 1.545 -- 0.66 steps/sec -- Step: 16k  <saved>
# Epoch: 81/200 -- Batch: 80/80 -- Loss: 1.542 -- 0.66 steps/sec -- Step: 16k  <saved>
# Epoch: 82/200 -- Batch: 80/80 -- Loss: 1.536 -- 0.66 steps/sec -- Step: 16k  <saved>
# Epoch: 83/200 -- Batch: 80/80 -- Loss: 1.498 -- 0.66 steps/sec -- Step: 16k  <saved>
# Epoch: 84/200 -- Batch: 80/80 -- Loss: 1.533 -- 0.66 steps/sec -- Step: 16k  <saved>
# Epoch: 85/200 -- Batch: 80/80 -- Loss: 1.536 -- 0.66 steps/sec -- Step: 16k  <saved>
# Epoch: 86/200 -- Batch: 80/80 -- Loss: 1.521 -- 0.66 steps/sec -- Step: 16k  <saved>
# Epoch: 87/200 -- Batch: 80/80 -- Loss: 1.555 -- 0.66 steps/sec -- Step: 16k  <saved>
# Epoch: 88/200 -- Batch: 80/80 -- Loss: 1.549 -- 0.66 steps/sec -- Step: 16k  <saved>
# Epoch: 89/200 -- Batch: 80/80 -- Loss: 1.507 -- 0.66 steps/sec -- Step: 16k  <saved>
# Epoch: 90/200 -- Batch: 80/80 -- Loss: 1.555 -- 0.66 steps/sec -- Step: 16k  <saved>
# Epoch: 91/200 -- Batch: 80/80 -- Loss: 1.523 -- 0.66 steps/sec -- Step: 16k  <saved>
# Epoch: 92/200 -- Batch: 80/80 -- Loss: 1.548 -- 0.66 steps/sec -- Step: 17k  <saved>
# Epoch: 93/200 -- Batch: 80/80 -- Loss: 1.550 -- 0.66 steps/sec -- Step: 17k  <saved>
# Epoch: 94/200 -- Batch: 80/80 -- Loss: 1.537 -- 0.66 steps/sec -- Step: 17k  <saved>
# Epoch: 95/200 -- Batch: 80/80 -- Loss: 1.485 -- 0.66 steps/sec -- Step: 17k  <saved>
# Epoch: 96/200 -- Batch: 80/80 -- Loss: 1.510 -- 0.66 steps/sec -- Step: 17k  <saved>
# Epoch: 97/200 -- Batch: 80/80 -- Loss: 1.552 -- 0.66 steps/sec -- Step: 17k  <saved>
# Epoch: 98/200 -- Batch: 80/80 -- Loss: 1.525 -- 0.66 steps/sec -- Step: 17k  <saved>
# Epoch: 99/200 -- Batch: 80/80 -- Loss: 1.541 -- 0.66 steps/sec -- Step: 17k  <saved>
# Epoch: 100/200 -- Batch: 80/80 -- Loss: 1.551 -- 0.66 steps/sec -- Step: 17k  <saved>
# Epoch: 101/200 -- Batch: 80/80 -- Loss: 1.557 -- 0.66 steps/sec -- Step: 17k  <saved>
# Epoch: 102/200 -- Batch: 80/80 -- Loss: 1.542 -- 0.66 steps/sec -- Step: 17k  <saved>
# Epoch: 103/200 -- Batch: 80/80 -- Loss: 1.482 -- 0.66 steps/sec -- Step: 17k  <saved>
# Epoch: 104/200 -- Batch: 80/80 -- Loss: 1.548 -- 0.66 steps/sec -- Step: 18k  <saved>
# Epoch: 105/200 -- Batch: 80/80 -- Loss: 1.502 -- 0.66 steps/sec -- Step: 18k  <saved>
# Epoch: 106/200 -- Batch: 80/80 -- Loss: 1.525 -- 0.66 steps/sec -- Step: 18k  <saved>
# Epoch: 107/200 -- Batch: 80/80 -- Loss: 1.483 -- 0.66 steps/sec -- Step: 18k  <saved>
# Epoch: 108/200 -- Batch: 80/80 -- Loss: 1.521 -- 0.66 steps/sec -- Step: 18k  <saved>
# Epoch: 109/200 -- Batch: 80/80 -- Loss: 1.515 -- 0.66 steps/sec -- Step: 18k  <saved>
# Epoch: 110/200 -- Batch: 80/80 -- Loss: 1.583 -- 0.66 steps/sec -- Step: 18k  <saved>
# Epoch: 111/200 -- Batch: 80/80 -- Loss: 1.526 -- 0.66 steps/sec -- Step: 18k  <saved>
# Epoch: 112/200 -- Batch: 80/80 -- Loss: 1.502 -- 0.66 steps/sec -- Step: 18k  <saved>
# Epoch: 113/200 -- Batch: 80/80 -- Loss: 1.527 -- 0.66 steps/sec -- Step: 18k  <saved>
# Epoch: 114/200 -- Batch: 80/80 -- Loss: 1.529 -- 0.66 steps/sec -- Step: 18k  <saved>
# Epoch: 115/200 -- Batch: 80/80 -- Loss: 1.562 -- 0.66 steps/sec -- Step: 18k  <saved>
# Epoch: 116/200 -- Batch: 80/80 -- Loss: 1.522 -- 0.66 steps/sec -- Step: 18k  <saved>
# Epoch: 117/200 -- Batch: 80/80 -- Loss: 1.516 -- 0.66 steps/sec -- Step: 19k  <saved>
# Epoch: 118/200 -- Batch: 80/80 -- Loss: 1.498 -- 0.66 steps/sec -- Step: 19k  <saved>
# Epoch: 119/200 -- Batch: 80/80 -- Loss: 1.534 -- 0.66 steps/sec -- Step: 19k  <saved>
# Epoch: 120/200 -- Batch: 80/80 -- Loss: 1.526 -- 0.66 steps/sec -- Step: 19k  <saved>
# Epoch: 121/200 -- Batch: 80/80 -- Loss: 1.536 -- 0.66 steps/sec -- Step: 19k  <saved>
# Epoch: 122/200 -- Batch: 80/80 -- Loss: 1.500 -- 0.66 steps/sec -- Step: 19k  <saved>
# Epoch: 123/200 -- Batch: 80/80 -- Loss: 1.499 -- 0.66 steps/sec -- Step: 19k  <saved>
# Epoch: 124/200 -- Batch: 80/80 -- Loss: 1.540 -- 0.66 steps/sec -- Step: 19k  <saved>
# Epoch: 125/200 -- Batch: 80/80 -- Loss: 1.507 -- 0.66 steps/sec -- Step: 19k  <saved>
# Epoch: 126/200 -- Batch: 80/80 -- Loss: 1.528 -- 0.66 steps/sec -- Step: 19k  <saved>
# Epoch: 127/200 -- Batch: 80/80 -- Loss: 1.520 -- 0.66 steps/sec -- Step: 19k  <saved>
# Epoch: 128/200 -- Batch: 80/80 -- Loss: 1.512 -- 0.66 steps/sec -- Step: 19k  <saved>
# Epoch: 129/200 -- Batch: 80/80 -- Loss: 1.508 -- 0.66 steps/sec -- Step: 20k  <saved>
# Epoch: 130/200 -- Batch: 80/80 -- Loss: 1.543 -- 0.66 steps/sec -- Step: 20k  <saved>
# Epoch: 131/200 -- Batch: 80/80 -- Loss: 1.490 -- 0.66 steps/sec -- Step: 20k  <saved>
# Epoch: 132/200 -- Batch: 80/80 -- Loss: 1.483 -- 0.66 steps/sec -- Step: 20k  <saved>
# Epoch: 133/200 -- Batch: 80/80 -- Loss: 1.524 -- 0.66 steps/sec -- Step: 20k  <saved>
# Epoch: 134/200 -- Batch: 80/80 -- Loss: 1.500 -- 0.66 steps/sec -- Step: 20k  <saved>
# Epoch: 135/200 -- Batch: 80/80 -- Loss: 1.505 -- 0.66 steps/sec -- Step: 20k  <saved>
# Epoch: 136/200 -- Batch: 80/80 -- Loss: 1.559 -- 0.66 steps/sec -- Step: 20k  <saved>
# Epoch: 137/200 -- Batch: 80/80 -- Loss: 1.494 -- 0.66 steps/sec -- Step: 20k  <saved>
# Epoch: 138/200 -- Batch: 80/80 -- Loss: 1.483 -- 0.66 steps/sec -- Step: 20k  <saved>
# Epoch: 139/200 -- Batch: 80/80 -- Loss: 1.534 -- 0.66 steps/sec -- Step: 20k  <saved>
# Epoch: 140/200 -- Batch: 80/80 -- Loss: 1.505 -- 0.66 steps/sec -- Step: 20k  <saved>
# Epoch: 141/200 -- Batch: 80/80 -- Loss: 1.538 -- 0.66 steps/sec -- Step: 20k  <saved>
# Epoch: 142/200 -- Batch: 80/80 -- Loss: 1.476 -- 0.66 steps/sec -- Step: 21k  <saved>
# Epoch: 143/200 -- Batch: 80/80 -- Loss: 1.479 -- 0.66 steps/sec -- Step: 21k  <saved>
# Epoch: 144/200 -- Batch: 80/80 -- Loss: 1.523 -- 0.66 steps/sec -- Step: 21k  <saved>
# Epoch: 145/200 -- Batch: 80/80 -- Loss: 1.508 -- 0.66 steps/sec -- Step: 21k  <saved>
# Epoch: 146/200 -- Batch: 80/80 -- Loss: 1.494 -- 0.66 steps/sec -- Step: 21k  <saved>
# Epoch: 147/200 -- Batch: 80/80 -- Loss: 1.525 -- 0.66 steps/sec -- Step: 21k  <saved>
# Epoch: 148/200 -- Batch: 80/80 -- Loss: 1.479 -- 0.66 steps/sec -- Step: 21k  <saved>
# Epoch: 149/200 -- Batch: 80/80 -- Loss: 1.500 -- 0.66 steps/sec -- Step: 21k  <saved>
# Epoch: 150/200 -- Batch: 80/80 -- Loss: 1.504 -- 0.66 steps/sec -- Step: 21k  <saved>
# Epoch: 151/200 -- Batch: 80/80 -- Loss: 1.510 -- 0.66 steps/sec -- Step: 21k  <saved>
# Epoch: 152/200 -- Batch: 80/80 -- Loss: 1.455 -- 0.66 steps/sec -- Step: 21k  <saved>
# Epoch: 153/200 -- Batch: 80/80 -- Loss: 1.476 -- 0.66 steps/sec -- Step: 21k  <saved>
# Epoch: 154/200 -- Batch: 80/80 -- Loss: 1.543 -- 0.66 steps/sec -- Step: 22k  <saved>
# Epoch: 155/200 -- Batch: 80/80 -- Loss: 1.504 -- 0.66 steps/sec -- Step: 22k  <saved>
# Epoch: 156/200 -- Batch: 80/80 -- Loss: 1.516 -- 0.66 steps/sec -- Step: 22k  <saved>
# Epoch: 157/200 -- Batch: 80/80 -- Loss: 1.515 -- 0.66 steps/sec -- Step: 22k  <saved>
# Epoch: 158/200 -- Batch: 80/80 -- Loss: 1.494 -- 0.66 steps/sec -- Step: 22k  <saved>
# Epoch: 159/200 -- Batch: 80/80 -- Loss: 1.499 -- 0.66 steps/sec -- Step: 22k  <saved>
# Epoch: 160/200 -- Batch: 80/80 -- Loss: 1.469 -- 0.66 steps/sec -- Step: 22k  <saved>
# Epoch: 161/200 -- Batch: 80/80 -- Loss: 1.468 -- 0.66 steps/sec -- Step: 22k  <saved>
# Epoch: 162/200 -- Batch: 80/80 -- Loss: 1.482 -- 0.66 steps/sec -- Step: 22k  <saved>
# Epoch: 163/200 -- Batch: 80/80 -- Loss: 1.448 -- 0.66 steps/sec -- Step: 22k  <saved>
# Epoch: 164/200 -- Batch: 80/80 -- Loss: 1.501 -- 0.66 steps/sec -- Step: 22k  <saved>
# Epoch: 165/200 -- Batch: 80/80 -- Loss: 1.519 -- 0.66 steps/sec -- Step: 22k  <saved>
# Epoch: 166/200 -- Batch: 80/80 -- Loss: 1.484 -- 0.66 steps/sec -- Step: 22k  <saved>
# Epoch: 167/200 -- Batch: 80/80 -- Loss: 1.529 -- 0.66 steps/sec -- Step: 23k  <saved>
# Epoch: 168/200 -- Batch: 80/80 -- Loss: 1.486 -- 0.66 steps/sec -- Step: 23k  <saved>
# Epoch: 169/200 -- Batch: 80/80 -- Loss: 1.440 -- 0.66 steps/sec -- Step: 23k  <saved>
# Epoch: 170/200 -- Batch: 80/80 -- Loss: 1.471 -- 0.66 steps/sec -- Step: 23k  <saved>
# Epoch: 171/200 -- Batch: 80/80 -- Loss: 1.502 -- 0.66 steps/sec -- Step: 23k  <saved>
# Epoch: 172/200 -- Batch: 80/80 -- Loss: 1.497 -- 0.66 steps/sec -- Step: 23k  <saved>
# Epoch: 173/200 -- Batch: 80/80 -- Loss: 1.477 -- 0.66 steps/sec -- Step: 23k  <saved>
# Epoch: 174/200 -- Batch: 80/80 -- Loss: 1.508 -- 0.66 steps/sec -- Step: 23k  <saved>
# Epoch: 175/200 -- Batch: 80/80 -- Loss: 1.471 -- 0.66 steps/sec -- Step: 23k  <saved>
# Epoch: 176/200 -- Batch: 80/80 -- Loss: 1.497 -- 0.66 steps/sec -- Step: 23k  <saved>
# Epoch: 177/200 -- Batch: 80/80 -- Loss: 1.482 -- 0.66 steps/sec -- Step: 23k  <saved>
# Epoch: 178/200 -- Batch: 80/80 -- Loss: 1.521 -- 0.66 steps/sec -- Step: 23k  <saved>
# Epoch: 179/200 -- Batch: 80/80 -- Loss: 1.516 -- 0.66 steps/sec -- Step: 24k  <saved>
# Epoch: 180/200 -- Batch: 80/80 -- Loss: 1.456 -- 0.66 steps/sec -- Step: 24k  <saved>
# Epoch: 181/200 -- Batch: 80/80 -- Loss: 1.553 -- 0.66 steps/sec -- Step: 24k  <saved>
# Epoch: 182/200 -- Batch: 80/80 -- Loss: 1.469 -- 0.66 steps/sec -- Step: 24k  <saved>
# Epoch: 183/200 -- Batch: 80/80 -- Loss: 1.506 -- 0.66 steps/sec -- Step: 24k  <saved>
# Epoch: 184/200 -- Batch: 80/80 -- Loss: 1.474 -- 0.66 steps/sec -- Step: 24k  <saved>
# Epoch: 185/200 -- Batch: 80/80 -- Loss: 1.459 -- 0.66 steps/sec -- Step: 24k  <saved>
# Epoch: 186/200 -- Batch: 80/80 -- Loss: 1.443 -- 0.66 steps/sec -- Step: 24k  <saved>
# Epoch: 187/200 -- Batch: 80/80 -- Loss: 1.466 -- 0.66 steps/sec -- Step: 24k  <saved>
# Epoch: 188/200 -- Batch: 80/80 -- Loss: 1.514 -- 0.66 steps/sec -- Step: 24k  <saved>
# Epoch: 189/200 -- Batch: 80/80 -- Loss: 1.493 -- 0.66 steps/sec -- Step: 24k  <saved>
# Epoch: 190/200 -- Batch: 80/80 -- Loss: 1.477 -- 0.66 steps/sec -- Step: 24k  <saved>
# Epoch: 191/200 -- Batch: 80/80 -- Loss: 1.485 -- 0.66 steps/sec -- Step: 24k  <saved>
# Epoch: 192/200 -- Batch: 80/80 -- Loss: 1.466 -- 0.66 steps/sec -- Step: 25k  <saved>
# Epoch: 193/200 -- Batch: 80/80 -- Loss: 1.502 -- 0.66 steps/sec -- Step: 25k  <saved>
# Epoch: 194/200 -- Batch: 80/80 -- Loss: 1.470 -- 0.66 steps/sec -- Step: 25k  <saved>
# Epoch: 195/200 -- Batch: 80/80 -- Loss: 1.455 -- 0.66 steps/sec -- Step: 25k  <saved>
# Epoch: 196/200 -- Batch: 80/80 -- Loss: 1.468 -- 0.66 steps/sec -- Step: 25k  <saved>
# Epoch: 197/200 -- Batch: 80/80 -- Loss: 1.463 -- 0.66 steps/sec -- Step: 25k  <saved>
# Epoch: 198/200 -- Batch: 80/80 -- Loss: 1.432 -- 0.66 steps/sec -- Step: 25k  <saved>
# Epoch: 199/200 -- Batch: 80/80 -- Loss: 1.516 -- 0.66 steps/sec -- Step: 25k  <saved>
# Epoch: 200/200 -- Batch: 80/80 -- Loss: 1.487 -- 0.66 steps/sec -- Step: 25k  <saved>

# %% [markdown]
# ## Generate Samples

# %%
def generate(samples=3, batched=True, target=11_000, overlap=550) :
    outputs = []
    k = step // 1000
    test_mels = [np.load(f'{DATA_PATH}mel/{id}.npy') for id in test_ids[:samples]]
    ground_truth = [np.load(f'{DATA_PATH}quant/{id}.npy') for id in test_ids[:samples]]
    for i, (gt, mel) in enumerate(zip(ground_truth, test_mels)) :
        print('\nGenerating: %i/%i' % (i+1, samples))
        gt = 2 * gt.astype(np.float32) / (2**bits - 1.) - 1.
        librosa.output.write_wav(f'{GEN_PATH}{k}k_steps_{i}_target.wav', gt, sr=sample_rate)
        if batched :
            save_str = f'{GEN_PATH}{k}k_steps_{i}_gen_batched_target{target}_overlap{overlap}.wav'
        else :    
            save_str = f'{GEN_PATH}{k}k_steps_{i}_gen_not_batched.wav'
        outputs.append(model.generate(mel, save_str, batched, target, overlap))
    
    for output in outputs:
        plot(output)

# %%
generate(batched=False)
# Out:
# Generating: 1/3
# 213100/213125 -- batch_size: 1 -- gen_rate: 0.6 kHz -- x_realtime: 0.0
# Generating: 2/3
# 42000/42075 -- batch_size: 1 -- gen_rate: 0.6 kHz -- x_realtime: 0.0
# Generating: 3/3
# 213300/213400 -- batch_size: 1 -- gen_rate: 0.6 kHz -- x_realtime: 0.0

# %%
generate(batched=True)
# Out:
# Generating: 1/3
# 228000/229900 -- batch_size: 19 -- gen_rate: 10.0 kHz -- x_realtime: 0.5
# Generating: 2/3
# 48000/48400 -- batch_size: 4 -- gen_rate: 2.0 kHz -- x_realtime: 0.1
# Generating: 3/3
# 228000/229900 -- batch_size: 19 -- gen_rate: 8.5 kHz -- x_realtime: 0.4

# %%
def generate_tamere(samples=1, batched=True, target=11_000, overlap=550) :
    outputs = []
    k = step // 1000
    test_mels = [np.load(f'{DATA_PATH}mel/lisqo-n8uql.npy') ]
    ground_truth = [np.load(f'{DATA_PATH}quant/lisqo-n8uql.npy')]
    for i, (gt, mel) in enumerate(zip(ground_truth, test_mels)) :
        print('\nGenerating: %i/%i' % (i+1, samples))
        gt = 2 * gt.astype(np.float32) / (2**bits - 1.) - 1.
        librosa.output.write_wav(f'{GEN_PATH}{k}lisqo-n8uql.wav{i}_target.wav', gt, sr=sample_rate)
        if batched :
            save_str = f'{GEN_PATH}{k}lisqo-n8uql{i}_gen_batched_target{target}_overlap{overlap}.wav'
        else :    
            save_str = f'{GEN_PATH}{k}lisqo-n8uql{i}_gen_not_batched.wav'
        outputs.append(model.generate(mel, save_str, batched, target, overlap))
    
    for output in outputs:
        plot(output)

# %%
generate_tamere(batched = False)
# Out:
# Generating: 1/1
# 243300/243375 -- batch_size: 1 -- gen_rate: 0.5 kHz -- x_realtime: 0.0
